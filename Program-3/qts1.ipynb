# %% [markdown]
# ### Q-1: Creation and loading different types of datasets in python using required libraries ?

# %% [markdown]
# ##### i: Creation using Panda

# %%
import pandas as pd

data = {
  "Name": ["Chikun", "Pikun", "Lipun"],
  "Age": ["21", "22", "23"],
  "GPA": ["8.7", "8.5", "8.9"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name Age  GPA
# 0  Chikun  21  8.7
# 1   Pikun  22  8.5
# 2   Lipun  23  8.9

# %% [markdown]
# ##### ii: Loading CSV dataset files using Pandas

# %%
df = pd.read_csv("StudentPerformance.csv")

print(df.head())
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %% [markdown]
# ##### iii: Loading dataset with scikit learn

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
Y = iris.target

print(X[:5])
print(Y[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0 0 0 0 0]
