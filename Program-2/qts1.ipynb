# %% [markdown]
# ##### Q-1: Create a series using pandas and display

# %%
import pandas as pd

index = ["i1", "i2", "i3"]
values = ["apple", "cherry", "grapes"]

pd.Series(index, values)
# Out:
# apple     i1
# cherry    i2
# grapes    i3
# dtype: object

# %% [markdown]
# ##### !!! For my own reference :

# %%
dictionary = {
  "Name": "Swabhiman", 
  "age": 19,
  "Gpa": 8.1
}

pd.Series(dictionary)
# Out:
# Name    Swabhiman
# age            19
# Gpa           8.1
# dtype: object
