# %% [markdown]
# ##### Q-6: Load datasets in a Data frame variable using pandas

# %%
import pandas as pd

# Use the below format like ("data.csv"/"data.xlsx") if the file is exist in the same folder -
# or else give the complete path of the file

data_frame1 = pd.read_csv("data.csv") # TO LOAD CSV FILE

df2 = pd.read_excel("data.xlsx")  # TO LOAD EXCEL FILE

df3 = pd.read_json("data.json")   # TO LOAD JSON FILE

df4 = pd.read_table("data.txt")   # TO LOAD TXT/CSV FILES

data = df4.head() # TO VIEW THE DATA
